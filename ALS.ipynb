# %%
from google.colab import drive
drive.mount('/content/drive')
artists_file = '/content/drive/MyDrive/data/artists.txt'
user_artists_file = '/content/drive/MyDrive/data/user_artists.txt'
user_artists_small_file = '/content/drive/MyDrive/data/user_artists_small.txt'
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import spsolve

def read_data(file_path):
    data = []
    with open(file_path, 'r') as file:
        next(file)
        for line in file:
            user, item, count = line.strip().split('\t')
            data.append((int(user), int(item), float(count)))
    return data

def read_artists(file_path):
    artist_dict = {}
    with open(file_path, 'r') as file:
        next(file)
        for line in file:
            artist_id, artist_name = line.strip().split('\t')
            artist_dict[int(artist_id)] = artist_name
    return artist_dict

def calculate_sparsity_ratio(data, num_users, num_items):
    num_interactions = len(data)
    num_zeros = num_users * num_items - num_interactions
    sparsity_ratio = num_interactions / num_zeros
    return sparsity_ratio

def initialize_matrices(num_users, num_items, f):
    np.random.seed(45)
    X = np.random.rand(num_users, f) * 0.01
    Y = np.random.rand(num_items, f) * 0.01
    return X, Y

def update_user_matrix(Y, data, num_users, num_items, f, reg_lambda):
    X = np.zeros((num_users, f))
    Y_tilde = Y.T @ Y
    for u in range(num_users):
        Cu_I = np.zeros((num_items, num_items))
        pu = np.zeros(num_items)
        for d in data:
            if d[0] == u:
                i = d[1]
                r = d[2]
                Cu_I[i, i] = alpha * r
                if r > 0:
                    pu[i] = 1
        Y_Cu = Y.T @ Cu_I
        A = Y_tilde + Y_Cu @ Y + reg_lambda * np.eye(f)
        b = Y_Cu @ pu
        xu = spsolve(csr_matrix(A), b)
        X[u] = xu
    return X

def update_item_matrix(X, data, num_users, num_items, f, reg_lambda):
    Y = np.zeros((num_items, f))
    X_tilde = X.T @ X
    for i in range(num_items):
        Ci_I = np.zeros((num_users, num_users))
        pi = np.zeros(num_users)
        for d in data:
            if d[1] == i:
                u = d[0]
                r = d[2]
                Ci_I[u, u] = alpha * r
                if r > 0:
                    pi[u] = 1
        X_Ci = X.T @ Ci_I
        A = X_tilde + X_Ci @ X + reg_lambda * np.eye(f)
        b = X_Ci @ pi
        yi = spsolve(csr_matrix(A), b)
        Y[i] = yi
    return Y

def calculate_objective(X, Y, data, alpha, reg_lambda):
    cost = 0
    for d in data:
        u, i, r = d
        cui = 1 + alpha * r
        pui = 1 if r > 0 else 0
        cost += cui * (pui - X[u] @ Y[i]) ** 2
    regularization = reg_lambda * (np.sum(np.square(X)) + np.sum(np.square(Y)))
    cost += regularization
    return cost

def ALS(data, num_users, num_items, f, alpha, reg_lambda, max_iter, artist_dict):
    X, Y = initialize_matrices(num_users, num_items, f)
    for iter in range(max_iter):
        X = update_user_matrix(Y, data, num_users, num_items, f, reg_lambda)
        Y = update_item_matrix(X, data, num_users, num_items, f, reg_lambda)
        objective = calculate_objective(X, Y, data, alpha, reg_lambda)
        print(f"Iteration {iter + 1}: Objective (Cimplicit) = {objective:.4f}")
    user_id = 1
    user_preferences = X[user_id] @ Y.T
    top_artist_ids = np.argsort(-user_preferences)[:5]
    top_artist_names = [artist_dict[artist_id] for artist_id in top_artist_ids]
    print(f"\nTop 5 artists for user {user_id} after {max_iter} iterations:")
    for artist_name in top_artist_names:
        print(artist_name)
    return X, Y

# Parameters
num_users = 100
num_items = 100
f = 3
reg_lambda = 0.01
max_iter = 100

# Read data
data = read_data(user_artists_small_file)
artist_dict = read_artists(artists_file)

# Calculate sparsity ratio
alpha = calculate_sparsity_ratio(data, num_users, num_items)
print(f"Sparsity ratio: {alpha:.4f}\n")

# Run ALS
X, Y = ALS(data, num_users, num_items, f, alpha, reg_lambda, max_iter, artist_dict)
# Out:
# Sparsity ratio: 0.0272
#
# Iteration 1: Objective (Cimplicit) = 1542.0289
# Iteration 2: Objective (Cimplicit) = 887.3567
# Iteration 3: Objective (Cimplicit) = 772.4329
# Iteration 4: Objective (Cimplicit) = 717.5634
# Iteration 5: Objective (Cimplicit) = 677.5370
# Iteration 6: Objective (Cimplicit) = 645.1720
# Iteration 7: Objective (Cimplicit) = 618.1496
# Iteration 8: Objective (Cimplicit) = 595.2172
# Iteration 9: Objective (Cimplicit) = 575.4415
# Iteration 10: Objective (Cimplicit) = 558.1262
# Iteration 11: Objective (Cimplicit) = 542.7853
# Iteration 12: Objective (Cimplicit) = 529.0692
# Iteration 13: Objective (Cimplicit) = 516.6841
# Iteration 14: Objective (Cimplicit) = 505.2837
# Iteration 15: Objective (Cimplicit) = 494.3811
# Iteration 16: Objective (Cimplicit) = 483.8022
# Iteration 17: Objective (Cimplicit) = 474.0700
# Iteration 18: Objective (Cimplicit) = 465.4517
# Iteration 19: Objective (Cimplicit) = 457.7525
# Iteration 20: Objective (Cimplicit) = 450.7145
# Iteration 21: Objective (Cimplicit) = 444.1598
# Iteration 22: Objective (Cimplicit) = 437.9839
# Iteration 23: Objective (Cimplicit) = 432.1294
# Iteration 24: Objective (Cimplicit) = 426.5589
# Iteration 25: Objective (Cimplicit) = 421.2315
# Iteration 26: Objective (Cimplicit) = 416.0792
# Iteration 27: Objective (Cimplicit) = 410.9911
# Iteration 28: Objective (Cimplicit) = 405.9272
# Iteration 29: Objective (Cimplicit) = 401.2118
# Iteration 30: Objective (Cimplicit) = 397.0838
# Iteration 31: Objective (Cimplicit) = 393.3640
# Iteration 32: Objective (Cimplicit) = 389.8946
# Iteration 33: Objective (Cimplicit) = 386.6069
# Iteration 34: Objective (Cimplicit) = 383.4698
# Iteration 35: Objective (Cimplicit) = 380.4671
# Iteration 36: Objective (Cimplicit) = 377.5893
# Iteration 37: Objective (Cimplicit) = 374.8303
# Iteration 38: Objective (Cimplicit) = 372.1857
# Iteration 39: Objective (Cimplicit) = 369.6522
# Iteration 40: Objective (Cimplicit) = 367.2263
# Iteration 41: Objective (Cimplicit) = 364.9044
# Iteration 42: Objective (Cimplicit) = 362.6821
# Iteration 43: Objective (Cimplicit) = 360.5551
# Iteration 44: Objective (Cimplicit) = 358.5183
# Iteration 45: Objective (Cimplicit) = 356.5671
# Iteration 46: Objective (Cimplicit) = 354.6965
# Iteration 47: Objective (Cimplicit) = 352.9022
# Iteration 48: Objective (Cimplicit) = 351.1798
# Iteration 49: Objective (Cimplicit) = 349.5252
# Iteration 50: Objective (Cimplicit) = 347.9347
# Iteration 51: Objective (Cimplicit) = 346.4046
# Iteration 52: Objective (Cimplicit) = 344.9318
# Iteration 53: Objective (Cimplicit) = 343.5129
# Iteration 54: Objective (Cimplicit) = 342.1453
# Iteration 55: Objective (Cimplicit) = 340.8260
# Iteration 56: Objective (Cimplicit) = 339.5527
# Iteration 57: Objective (Cimplicit) = 338.3228
# Iteration 58: Objective (Cimplicit) = 337.1342
# Iteration 59: Objective (Cimplicit) = 335.9847
# Iteration 60: Objective (Cimplicit) = 334.8724
# Iteration 61: Objective (Cimplicit) = 333.7955
# Iteration 62: Objective (Cimplicit) = 332.7523
# Iteration 63: Objective (Cimplicit) = 331.7410
# Iteration 64: Objective (Cimplicit) = 330.7603
# Iteration 65: Objective (Cimplicit) = 329.8087
# Iteration 66: Objective (Cimplicit) = 328.8848
# Iteration 67: Objective (Cimplicit) = 327.9875
# Iteration 68: Objective (Cimplicit) = 327.1155
# Iteration 69: Objective (Cimplicit) = 326.2677
# Iteration 70: Objective (Cimplicit) = 325.4432
# Iteration 71: Objective (Cimplicit) = 324.6408
# Iteration 72: Objective (Cimplicit) = 323.8598
# Iteration 73: Objective (Cimplicit) = 323.0991
# Iteration 74: Objective (Cimplicit) = 322.3581
# Iteration 75: Objective (Cimplicit) = 321.6360
# Iteration 76: Objective (Cimplicit) = 320.9319
# Iteration 77: Objective (Cimplicit) = 320.2453
# Iteration 78: Objective (Cimplicit) = 319.5754
# Iteration 79: Objective (Cimplicit) = 318.9217
# Iteration 80: Objective (Cimplicit) = 318.2835
# Iteration 81: Objective (Cimplicit) = 317.6603
# Iteration 82: Objective (Cimplicit) = 317.0516
# Iteration 83: Objective (Cimplicit) = 316.4568
# Iteration 84: Objective (Cimplicit) = 315.8755
# Iteration 85: Objective (Cimplicit) = 315.3073
# Iteration 86: Objective (Cimplicit) = 314.7517
# Iteration 87: Objective (Cimplicit) = 314.2082
# Iteration 88: Objective (Cimplicit) = 313.6766
# Iteration 89: Objective (Cimplicit) = 313.1564
# Iteration 90: Objective (Cimplicit) = 312.6472
# Iteration 91: Objective (Cimplicit) = 312.1487
# Iteration 92: Objective (Cimplicit) = 311.6607
# Iteration 93: Objective (Cimplicit) = 311.1828
# Iteration 94: Objective (Cimplicit) = 310.7146
# Iteration 95: Objective (Cimplicit) = 310.2559
# Iteration 96: Objective (Cimplicit) = 309.8065
# Iteration 97: Objective (Cimplicit) = 309.3661
# Iteration 98: Objective (Cimplicit) = 308.9344
# Iteration 99: Objective (Cimplicit) = 308.5112
# Iteration 100: Objective (Cimplicit) = 308.0962
#
# Top 5 artists for user 1 after 100 iterations:
# Icon of Coil
# Pleq
# Segue
# Max Richter
# Covenant
